# %% [markdown]
# # Stock Prices

# %% [markdown]
# ![stock-prices.png](attachment:stock-prices.png)

# %% [markdown]
# # Stock Sells

# %% [markdown]
# ![stock-sells.png](attachment:stock-sells.png)

# %% [markdown]
# # Earnings

# %% [markdown]
# ![earnings.png](attachment:earnings.png)

# %% [markdown]
# # Profits

# %% [markdown]
# ![profits.png](attachment:profits.png)

# %% [markdown]
# # Complete Analysis Bar 1

# %% [markdown]
# ![complete-analysis-bar1.png](attachment:complete-analysis-bar1.png)

# %% [markdown]
# # Complete Analysis Plot 1

# %% [markdown]
# ![complete-analysis-plot1.png](attachment:complete-analysis-plot1.png)

# %% [markdown]
# # Complete Analysis Bar 2

# %% [markdown]
# ![complete-analysis-bar2.png](attachment:complete-analysis-bar2.png)

# %% [markdown]
# # Complete Analysis Plot 2

# %% [markdown]
# ![complete-analysis-plot2.png](attachment:complete-analysis-plot2.png)
